# %% [markdown]
# ## Data Exploration

# %% [markdown]
# ### Encoding in python

# %%
import pandas as pd
import numpy as np

# %%
tips = pd.read_csv("tips_data.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-2-d8e01b9290bb> in <module>
# ----> 1 tips = pd.read_csv("tips_data.csv")
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._get_header()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xfe in position 0: invalid start byte

# %%
# Chardet: The Universal Character Encoding Detector (ASCII, UTF-8, UTF-16, UTF-32,Big5, GB2312, EUC-TW, HZ-GB-2312 etc)
import chardet

# %%
with open("tips_data.csv", 'rb') as rawdata:
    result = chardet.detect(rawdata.read(2000))

# check what the character encoding might be
print(result)
# Out:
# {'encoding': 'UTF-16', 'confidence': 1.0, 'language': ''}

# %% [markdown]
# So chardet is 100%  confidence that the right encoding is "UTF-16". Let's see if that's correct:

# %%
# read in the file with the encoding detected by chardet
tips = pd.read_csv("tips_data.csv", encoding='UTF-16')

# %% [markdown]
# ### Data Cleaning

# %%
tips.head(20)
# Out:
#    Order_id  total_bill   tip  gender smoker  day    time  size
# 0     ORD_1       16.99  1.01  Female     No  Sun  Dinner     2
# 1     ORD_2       10.34  1.66    Male     No  sun  Dinner     3
# 2     ORD_3         NaN  3.50    Male     No  Sun  Dinner     3
# 3     ORD_4       23.68  3.31    Male     No  Sun  Dinner     2
# 4     ORD_5       24.59  3.61  Female     No  Sun  Dinner     4
# 5     ORD_6       25.29  4.71    Male     No  sun  Dinner     4
# 6     ORD_7        8.77  2.00    Male     No  Sun  Dinner     2
# 7     ORD_8       26.88  3.12    Male     No  Sun  Dinner     4
# 8     ORD_9       15.04  1.96    Male     No  Sun  Dinner     2
# 9    ORD_10       14.78  3.23    Male     No  Sun  Dinner     2
# 10   ORD_11       10.27  1.71    Male     No  Sun  Dinner     2
# 11   ORD_12       35.26  5.00  Female     No  Sun  Dinner     4
# 12   ORD_13       15.42  1.57    Male     No  Sun  Dinner     2
# 13   ORD_14         NaN  3.00    Male     No  Sun  Dinner     4
# 14   ORD_15       14.83  3.02  Female     No  Sun  Dinner     2
# 15   ORD_16       21.58  3.92    Male     No  Sun  Dinner     2
# 16   ORD_17       10.33  1.67  Female     No  Sun  Dinner     3
# 17   ORD_18       16.29  3.71    Male     No  Sun  Dinner     3
# 18   ORD_19       16.97  3.50  Female     No  Sun  Dinner     3
# 19   ORD_20         NaN  3.35    Male     No  Sat  Dinner     3

# %%
tips.tail(10)
# Out:
#     Order_id  total_bill   tip  gender smoker   day    time  size
# 234  ORD_235       15.53  3.00    Male    Yes   Sat  Dinner     2
# 235  ORD_236       10.07  1.25    Male     No   Sat  Dinner     2
# 236  ORD_237       12.60  1.00    Male    Yes   Sat  Dinner     2
# 237  ORD_238       32.83  1.17    Male    Yes   Sat  Dinner     2
# 238  ORD_239       35.83  4.67  Female     No   Sat  Dinner     3
# 239  ORD_240       29.03  5.92    Male     No   Sat  Dinner     3
# 240  ORD_241       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241  ORD_242       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242  ORD_243       17.82  1.75    Male     No   Sat  Dinner     2
# 243  ORD_244       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips.sample(20)
# Out:
#     Order_id  total_bill   tip  gender smoker   day    time  size
# 20    ORD_21       17.92  4.08    Male     No   Sat  Dinner     2
# 82    ORD_83       10.07  1.83  Female     No  Thur   Lunch     1
# 201  ORD_202       12.74  2.01  Female    Yes  Thur   Lunch     2
# 155  ORD_156       29.85  5.14  Female     No   Sun  Dinner     5
# 135  ORD_136        8.51  1.25  Female     No  Thur   Lunch     2
# 134  ORD_135       18.26  3.25  Female     No  Thur   Lunch     2
# 52    ORD_53       34.81  5.20  Female     No   Sun  Dinner     4
# 172  ORD_173        7.25  5.15    Male    Yes   Sun  Dinner     2
# 1      ORD_2       10.34  1.66    Male     No   sun  Dinner     3
# 151  ORD_152       13.13  2.00    Male     No   Sun  Dinner     2
# 35    ORD_36       24.06  3.60    Male     No   Sat  Dinner     3
# 118  ORD_119       12.43  1.80  Female     No  Thur   Lunch     2
# 158  ORD_159       13.39  2.61  Female     No   Sun  Dinner     2
# 171  ORD_172       15.81  3.16    Male    Yes   Sat  Dinner     2
# 126  ORD_127        8.52  1.48    Male     No  Thur   Lunch     2
# 56    ORD_57         NaN  3.00    Male    Yes   Sat  Dinner     4
# 34    ORD_35       17.78  3.27    Male     No   Sat  Dinner     2
# 119  ORD_120       24.08  2.92  Female     No  Thur   Lunch     4
# 140  ORD_141       17.47  3.50  Female     No  Thur   Lunch     2
# 137  ORD_138       14.15  2.00  Female     No  Thur   Lunch     2

# %%
tips.columns
# Out:
# Index(['Order_id', 'total_bill', 'tip', 'gender', 'smoker', 'day', 'time',
#        'size'],
#       dtype='object')

# %%
tips.shape
# Out:
# (244, 8)

# %% [markdown]
# ### Data Inspection

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Order_id    244 non-null    object
#  1   total_bill  231 non-null    float64
#  2   tip         244 non-null    float64
#  3   gender      244 non-null    object
#  4   smoker      244 non-null    object
#  5   day         244 non-null    object
#  6   time        244 non-null    object
#  7   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 15.4+ KB

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  231.000000  244.000000  244.000000
# mean    19.556667    2.998279    2.569672
# std      8.803428    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.215000    2.000000    2.000000
# 50%     17.460000    2.900000    2.000000
# 75%     24.035000    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.head()
# Out:
#   Order_id  total_bill   tip  gender smoker  day    time  size
# 0    ORD_1       16.99  1.01  Female     No  Sun  Dinner     2
# 1    ORD_2       10.34  1.66    Male     No  sun  Dinner     3
# 2    ORD_3         NaN  3.50    Male     No  Sun  Dinner     3
# 3    ORD_4       23.68  3.31    Male     No  Sun  Dinner     2
# 4    ORD_5       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# identify the unique number of Days in Tips
len(tips['day'].unique())
# Out:
# 6

# %%
# displaying frequencies of each category
tips['day'].value_counts()
# Out:
# Sat     86
# Sun     74
# Thur    62
# Fri     19
# sun      2
# sat      1
# Name: day, dtype: int64

# %%
# converting column to lowercase
tips['day'] = tips['day'].str.lower()
tips.head()
# Out:
#   Order_id  total_bill   tip  gender smoker  day    time  size
# 0    ORD_1       16.99  1.01  Female     No  sun  Dinner     2
# 1    ORD_2       10.34  1.66    Male     No  sun  Dinner     3
# 2    ORD_3         NaN  3.50    Male     No  sun  Dinner     3
# 3    ORD_4       23.68  3.31    Male     No  sun  Dinner     2
# 4    ORD_5       24.59  3.61  Female     No  sun  Dinner     4

# %%
# Look at unique values again
len(tips['day'].unique())
# Out:
# 4

# %%
# displaying frequencies of each category
tips['day'].value_counts()
# Out:
# sat     87
# sun     76
# thur    62
# fri     19
# Name: day, dtype: int64

# %%
# displaying % of each category
tips['day'].value_counts(normalize=True)*100
# Out:
# sat     35.655738
# sun     31.147541
# thur    25.409836
# fri      7.786885
# Name: day, dtype: float64

# %%
tips.head()
# Out:
#   Order_id  total_bill   tip  gender smoker  day    time  size
# 0    ORD_1       16.99  1.01  Female     No  sun  Dinner     2
# 1    ORD_2       10.34  1.66    Male     No  sun  Dinner     3
# 2    ORD_3         NaN  3.50    Male     No  sun  Dinner     3
# 3    ORD_4       23.68  3.31    Male     No  sun  Dinner     2
# 4    ORD_5       24.59  3.61  Female     No  sun  Dinner     4

# %% [markdown]
# #### Loading the Rating data

# %%
rating = pd.read_csv("rating.csv")

# %%
rating.head()
# Out:
#   Ord_id  rating
# 0  ORD_1     1.0
# 1  ORD_2     1.0
# 2  ORD_3     NaN
# 3  ORD_4     4.0
# 4  ORD_5     1.0

# %%
# merging the two dfs
master = pd.merge(tips, rating, how="inner", left_on="Order_id", right_on="Ord_id")
master.head()
# Out:
#   Order_id  total_bill   tip  gender smoker  day    time  size Ord_id  rating
# 0    ORD_1       16.99  1.01  Female     No  sun  Dinner     2  ORD_1     1.0
# 1    ORD_2       10.34  1.66    Male     No  sun  Dinner     3  ORD_2     1.0
# 2    ORD_3         NaN  3.50    Male     No  sun  Dinner     3  ORD_3     NaN
# 3    ORD_4       23.68  3.31    Male     No  sun  Dinner     2  ORD_4     4.0
# 4    ORD_5       24.59  3.61  Female     No  sun  Dinner     4  ORD_5     1.0

# %%
# removing redundant columns
master =  master.drop(['Ord_id'], axis=1) 
master.head()
# Out:
#   Order_id  total_bill   tip  gender smoker  day    time  size  rating
# 0    ORD_1       16.99  1.01  Female     No  sun  Dinner     2     1.0
# 1    ORD_2       10.34  1.66    Male     No  sun  Dinner     3     1.0
# 2    ORD_3         NaN  3.50    Male     No  sun  Dinner     3     NaN
# 3    ORD_4       23.68  3.31    Male     No  sun  Dinner     2     4.0
# 4    ORD_5       24.59  3.61  Female     No  sun  Dinner     4     1.0

# %% [markdown]
# ## Missing Value Treatment
#
# Let's now move to missing value treatment.
#
# Let's have a look at the number of missing values in master dataframe.

# %%
# missing values in master df
master.isnull().sum()
# Out:
# Order_id       0
# total_bill    13
# tip            0
# gender         0
# smoker         0
# day            0
# time           0
# size           0
# rating         9
# dtype: int64

# %% [markdown]
# **Observation**: There are 13 missing values in Total Bill column. We need to fill them appropriately

# %% [markdown]
# Let's look at the fraction of missing values in the columns.

# %%
# summing up the missing values (column-wise) and displaying fraction of NaNs
round(100*(master.isnull().sum()/len(master.index)), 3)
# Out:
# Order_id      0.000
# total_bill    5.328
# tip           0.000
# gender        0.000
# smoker        0.000
# day           0.000
# time          0.000
# size          0.000
# rating        3.689
# dtype: float64

# %%
master.head()
# Out:
#   Order_id  total_bill   tip  gender smoker  day    time  size  rating
# 0    ORD_1       16.99  1.01  Female     No  sun  Dinner     2     1.0
# 1    ORD_2       10.34  1.66    Male     No  sun  Dinner     3     1.0
# 2    ORD_3         NaN  3.50    Male     No  sun  Dinner     3     NaN
# 3    ORD_4       23.68  3.31    Male     No  sun  Dinner     2     4.0
# 4    ORD_5       24.59  3.61  Female     No  sun  Dinner     4     1.0

# %%
master['total_bill'].describe()
# Out:
# count    231.000000
# mean      19.556667
# std        8.803428
# min        3.070000
# 25%       13.215000
# 50%       17.460000
# 75%       24.035000
# max       50.810000
# Name: total_bill, dtype: float64

# %%
## Fill NaN for total_bill based on Median 
median = master['total_bill'].median()
print(median)
# Out:
# 17.46

# %%
master['total_bill'] = master['total_bill'].fillna(median)

# %%
master.isnull().sum()
# Out:
# Order_id      0
# total_bill    0
# tip           0
# gender        0
# smoker        0
# day           0
# time          0
# size          0
# Ord_id        0
# rating        9
# dtype: int64

# %% [markdown]
# **Observation**: No Missing values in total_bills now!

# %%
master.head()
# Out:
#   Order_id  total_bill   tip  gender smoker  day    time  size Ord_id  rating
# 0    ORD_1       16.99  1.01  Female     No  sun  Dinner     2  ORD_1     1.0
# 1    ORD_2       10.34  1.66    Male     No  sun  Dinner     3  ORD_2     1.0
# 2    ORD_3       17.46  3.50    Male     No  sun  Dinner     3  ORD_3     NaN
# 3    ORD_4       23.68  3.31    Male     No  sun  Dinner     2  ORD_4     4.0
# 4    ORD_5       24.59  3.61  Female     No  sun  Dinner     4  ORD_5     1.0

# %%
master.shape
# Out:
# (244, 10)

# %%
# removing NaNs in rating
master = master[~np.isnan(master['rating'])]    # can also use pd.isnull()
master.isnull().sum()
# Out:
# Order_id      0
# total_bill    0
# tip           0
# gender        0
# smoker        0
# day           0
# time          0
# size          0
# Ord_id        0
# rating        0
# dtype: int64

# %%
master.shape
# Out:
# (235, 10)

# %% [markdown]
# ### Sorting dataframes

# %%
sorted_by_tips = master.sort_values(by="tip",ascending=False)
sorted_by_tips.head(5)
# Out:
#     Order_id  total_bill    tip gender smoker   day    time  size   Ord_id  \
# 170  ORD_171       50.81  10.00   Male    Yes   sat  Dinner     3  ORD_171
# 212  ORD_213       48.33   9.00   Male     No   sat  Dinner     4  ORD_213
# 23    ORD_24       39.42   7.58   Male     No   sat  Dinner     4   ORD_24
# 59    ORD_60       17.46   6.73   Male     No   sat  Dinner     4   ORD_60
# 141  ORD_142       34.30   6.70   Male     No  thur   Lunch     6  ORD_142
#
#      rating
# 170     2.0
# 212     3.0
# 23      2.0
# 59      4.0
# 141     1.0

# %%
# top 5 tips
top_5_tips = sorted_by_tips[:5]
top_5_tips
# Out:
#     Order_id  total_bill    tip gender smoker   day    time  size   Ord_id  \
# 170  ORD_171       50.81  10.00   Male    Yes   sat  Dinner     3  ORD_171
# 212  ORD_213       48.33   9.00   Male     No   sat  Dinner     4  ORD_213
# 23    ORD_24       39.42   7.58   Male     No   sat  Dinner     4   ORD_24
# 59    ORD_60       17.46   6.73   Male     No   sat  Dinner     4   ORD_60
# 141  ORD_142       34.30   6.70   Male     No  thur   Lunch     6  ORD_142
#
#      rating
# 170     2.0
# 212     3.0
# 23      2.0
# 59      4.0
# 141     1.0

# %%
top_5_tips
# Out:
#     Order_id  total_bill    tip gender smoker   day    time  size   Ord_id  \
# 170  ORD_171       50.81  10.00   Male    Yes   sat  Dinner     3  ORD_171
# 212  ORD_213       48.33   9.00   Male     No   sat  Dinner     4  ORD_213
# 23    ORD_24       39.42   7.58   Male     No   sat  Dinner     4   ORD_24
# 59    ORD_60       17.46   6.73   Male     No   sat  Dinner     4   ORD_60
# 141  ORD_142       34.30   6.70   Male     No  thur   Lunch     6  ORD_142
#
#      rating
# 170     2.0
# 212     3.0
# 23      2.0
# 59      4.0
# 141     1.0

# %% [markdown]
# ### Filtering only High rated orders

# %%
# filtering for 4 and 5 rating
high_rating = master[(master.rating == 4) | (master.rating == 5)]
high_rating.head()
# Out:
#    Order_id  total_bill   tip  gender smoker  day    time  size  Ord_id  \
# 3     ORD_4       23.68  3.31    Male     No  sun  Dinner     2   ORD_4
# 7     ORD_8       26.88  3.12    Male     No  sun  Dinner     4   ORD_8
# 8     ORD_9       15.04  1.96    Male     No  sun  Dinner     2   ORD_9
# 10   ORD_11       10.27  1.71    Male     No  sun  Dinner     2  ORD_11
# 11   ORD_12       35.26  5.00  Female     No  sun  Dinner     4  ORD_12
#
#     rating
# 3      4.0
# 7      5.0
# 8      4.0
# 10     5.0
# 11     5.0

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ## Exploratory Data Analytics
#
# Let's now spend some time doing what is arguably the most important step - **understanding the data**.

# %% [markdown]
# ### Visualising Numeric Variables
#
# Let's make a pairplot of all the numeric variables

# %%
# Data Visualisation

import matplotlib.pyplot as plt 
import seaborn as sns

# %%
sns.pairplot(tips)
plt.show()

# %% [markdown]
# #### Visualising Categorical Variables
#
# As you might have noticed, there are a few categorical variables as well. Let's make a boxplot for some of these variables.

# %%
plt.figure(figsize=(20, 10))
plt.subplot(4,2,1)
sns.boxplot(x = 'gender', y = 'tip', data = tips)
plt.subplot(2,2,2)
sns.boxplot(x = 'smoker', y = 'tip', data = tips)
plt.subplot(2,2,3)
sns.boxplot(x = 'day', y = 'tip', data = tips)
plt.subplot(2,2,4)
sns.boxplot(x = 'time', y = 'tip', data = tips)
plt.show()

# %% [markdown]
# ## Changing from wide format to long format

# %%
data = {'Name': ['John', 'Smith', 'Liz','Tom','Andy'], 
        'City': ['New York', 'Atlanta', 'Chicago','Boston','Atlanta'], 
        'Red': [1, 0, 0,1,0], 
        'Yellow': [0,0,1,0,1],
        'Black':[0,1,0,0,0]}
wide_df = pd.DataFrame(data)
wide_df
# Out:
#     Name      City  Red  Yellow  Black
# 0   John  New York    1       0      0
# 1  Smith   Atlanta    0       0      1
# 2    Liz   Chicago    0       1      0
# 3    Tom    Boston    1       0      0
# 4   Andy   Atlanta    0       1      0

# %%
help(pd.melt)
# Out:
# Help on function melt in module pandas.core.reshape.melt:
#
# melt(frame: pandas.core.frame.DataFrame, id_vars=None, value_vars=None, var_name=None, value_name='value', col_level=None) -> pandas.core.frame.DataFrame
#     Unpivot a DataFrame from wide to long format, optionally leaving identifiers set.
#
#     This function is useful to massage a DataFrame into a format where one
#     or more columns are identifier variables (`id_vars`), while all other
#     columns, considered measured variables (`value_vars`), are "unpivoted" to
#     the row axis, leaving just two non-identifier columns, 'variable' and
#     'value'.
#
#     Parameters
#     ----------
#     id_vars : tuple, list, or ndarray, optional
#         Column(s) to use as identifier variables.
#     value_vars : tuple, list, or ndarray, optional
#         Column(s) to unpivot. If not specified, uses all columns that
#         are not set as `id_vars`.
#     var_name : scalar
#         Name to use for the 'variable' column. If None it uses
#         ``frame.columns.name`` or 'variable'.
#     value_name : scalar, default 'value'
#         Name to use for the 'value' column.
#     col_level : int or str, optional
#         If columns are a MultiIndex then use this level to melt.
#
#     Returns
#     -------
#     DataFrame
#         Unpivoted DataFrame.
#
#     See Also
#     --------
#     DataFrame.melt
#     pivot_table
#     DataFrame.pivot
#     Series.explode
#
#     Examples
#     --------
#     >>> df = pd.DataFrame({'A': {0: 'a', 1: 'b', 2: 'c'},
#     ...                    'B': {0: 1, 1: 3, 2: 5},
#     ...                    'C': {0: 2, 1: 4, 2: 6}})
#     >>> df
#        A  B  C
#     0  a  1  2
#     1  b  3  4
#     2  c  5  6
#
#     >>> pd.melt(df, id_vars=['A'], value_vars=['B'])
#        A variable  value
#     0  a        B      1
#     1  b        B      3
#     2  c        B      5
#
#     >>> pd.melt(df, id_vars=['A'], value_vars=['B', 'C'])
#        A variable  value
#     0  a        B      1
#     1  b        B      3
#     2  c        B      5
#     3  a        C      2
#     4  b        C      4
#     5  c        C      6
#
#     The names of 'variable' and 'value' columns can be customized:
#
#     >>> pd.melt(df, id_vars=['A'], value_vars=['B'],
#     ...         var_name='myVarname', value_name='myValname')
#        A myVarname  myValname
#     0  a         B          1
#     1  b         B          3
#     2  c         B          5
#
#     If you have multi-index columns:
#
#     >>> df.columns = [list('ABC'), list('DEF')]
#     >>> df
#        A  B  C
#        D  E  F
#     0  a  1  2
#     1  b  3  4
#     2  c  5  6
#
#     >>> pd.melt(df, col_level=0, id_vars=['A'], value_vars=['B'])
#        A variable  value
#     0  a        B      1
#     1  b        B      3
#     2  c        B      5
#
#     >>> pd.melt(df, id_vars=[('A', 'D')], value_vars=[('B', 'E')])
#       (A, D) variable_0 variable_1  value
#     0      a          B          E      1
#     1      b          B          E      3
#     2      c          B          E      5

# %%
wide_df.head()
# Out:
#     Name      City  Red  Yellow  Black
# 0   John  New York    1       0      0
# 1  Smith   Atlanta    0       0      1
# 2    Liz   Chicago    0       1      0
# 3    Tom    Boston    1       0      0
# 4   Andy   Atlanta    0       1      0

# %%
# store the value and id variables in two separate arrays

# store the value variables in one Series
value_vars = list(wide_df.columns[2:])

# take the setdiff() to get the rest of the variables
id_vars = list(np.setdiff1d(wide_df.columns, value_vars))

print(value_vars, "\n")
print(id_vars)
# Out:
# ['Red', 'Yellow', 'Black']
#
# ['City', 'Name']

# %%
wide_df
# Out:
#     Name      City  Red  Yellow  Black
# 0   John  New York    1       0      0
# 1  Smith   Atlanta    0       0      1
# 2    Liz   Chicago    0       1      0
# 3    Tom    Boston    1       0      0
# 4   Andy   Atlanta    0       1      0

# %%
# convert into long
long_df = pd.melt(wide_df, 
        id_vars = id_vars, 
        value_vars = value_vars)
long_df
# Out:
#         City   Name variable  value
# 0   New York   John      Red      1
# 1    Atlanta  Smith      Red      0
# 2    Chicago    Liz      Red      0
# 3     Boston    Tom      Red      1
# 4    Atlanta   Andy      Red      0
# 5   New York   John   Yellow      0
# 6    Atlanta  Smith   Yellow      0
# 7    Chicago    Liz   Yellow      1
# 8     Boston    Tom   Yellow      0
# 9    Atlanta   Andy   Yellow      1
# 10  New York   John    Black      0
# 11   Atlanta  Smith    Black      1
# 12   Chicago    Liz    Black      0
# 13    Boston    Tom    Black      0
# 14   Atlanta   Andy    Black      0

# %%
# remove rows having value=0
long_df = long_df[long_df['value']==1]

# %%
long_df
# Out:
#         City   Name variable  value
# 0   New York   John      Red      1
# 3     Boston    Tom      Red      1
# 7    Chicago    Liz   Yellow      1
# 9    Atlanta   Andy   Yellow      1
# 11   Atlanta  Smith    Black      1

# %%
long_df = long_df.drop('value', axis=1)

# %%
# look at the new df
long_df
# Out:
#         City   Name variable
# 0   New York   John      Red
# 3     Boston    Tom      Red
# 7    Chicago    Liz   Yellow
# 9    Atlanta   Andy   Yellow
# 11   Atlanta  Smith    Black

# %%
# renaming the 'variable' column
long_df = long_df.rename(columns={'variable': 'Color of Car'})
long_df
# Out:
#         City   Name Color of Car
# 0   New York   John          Red
# 3     Boston    Tom          Red
# 7    Chicago    Liz       Yellow
# 9    Atlanta   Andy       Yellow
# 11   Atlanta  Smith        Black

# %% [markdown]
# ### -----------------------------------------------------------THANK YOU --------------------------------------------------------------------------------
